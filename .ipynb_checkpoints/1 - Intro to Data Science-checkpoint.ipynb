# %% [markdown]
# ## pandas dataframes, matplotlib and seaborn

# %% [markdown]
# A dataframe is a data structure for working with tables, as you will see throughout this notebook.
#
# For more details, check the documentation: https://pandas.pydata.org/pandas-docs/stable/index.html
#
# **matplotlib** and **seaborn** are libraries to make all sorts of plots for exploratory data analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br>
#
#
#
#
# We begin by reading the csv file of the monitoring records of a job. This automatically created a dataframe object for us. Then we check the first 5 rows of data.
#
# ( I don't know why the reader function added a column called 'Unnamed: 10', but this isn't a problem, we can just drop
# (delete) this column later on. )
#
#
#
#
# <br>

# %%
csvfile = 'Monitoring.csv'
df = pd.read_csv(csvfile, sep=';')
df.head()
# Out:
#   Record        Complete Date  Min Bat Voltage  Max Bat Voltage  \
# 0   MONI  04/04/2017 16:32:52         13.98047         13.98828
# 1   MONI  04/04/2017 16:37:59         13.97656         13.98047
# 2   MONI  04/04/2017 16:43:08         13.97656         13.98047
# 3   MONI  04/04/2017 16:48:26         13.97266         13.97656
# 4   MONI  04/04/2017 16:53:46         13.96875         13.97266
#
#    Battery Current  3.3V IO  5V Analogic  3.3V Permanent  Board Temperature  \
# 0         0.011719   3.3125      4.90625         3.31250                 23
# 1         0.011719   3.3125      4.90625         3.28125                 23
# 2         0.011719   3.3125      4.90625         3.31250                 23
# 3         0.011719   3.3125      4.90625         3.31250                 23
# 4         0.011719   3.3125      4.90625         3.31250                 22
#
#    Stack Temperature  Unnamed: 10
# 0                255          NaN
# 1                255          NaN
# ...

# %% [markdown]
# <br>
#
#
#
# Now, we can use the .describe() method to see some useful statistics about our data.
#
#
#
#
# <br>

# %%
df.describe()
# Out:
#        Min Bat Voltage  Max Bat Voltage  Battery Current      3.3V IO  \
# count      3191.000000      3191.000000      3191.000000  3191.000000
# mean         14.252525        14.402040         0.012299     3.284903
# std           1.023774         0.963119         0.002127     0.010042
# min           6.589844         6.609375         0.007812     3.281250
# 25%          14.050780        14.535160         0.011719     3.281250
# 50%          14.578130        14.640630         0.011719     3.281250
# 75%          14.699220        14.714840         0.011719     3.281250
# max          14.917970        14.929690         0.027344     3.312500
#
#        5V Analogic  3.3V Permanent  Board Temperature  Stack Temperature  \
# count  3191.000000     3191.000000        3191.000000             3191.0
# mean      4.879926        3.283884         117.923848              255.0
# std       0.011443        0.008684          31.523423                0.0
# ...

# %% [markdown]
# We observe there are no values missing, since the **count** is the same for every feature.
#
# In this example we don't need to worry about strategies for filling missing values, which can be a rather complicated task.
#
# Also we see that some columns have insignificant standard deviation (std), so we can safely drop them as they probably do not correlate do any of the other columns.

# %%
df.drop(columns=['Unnamed: 10', 'Stack Temperature'], inplace=True)

# %% [markdown]
# Now let's see a correlation matrix for all the variables and make it into a heatmap for an even nicer visualization.
# We will do that using the seaborn library.
#
# We begin by creating the correlation matrix, then we create a Figure and an Axes object, defined under the matplotlib.pyplot library. It is to the Axes object that we can apply methods such as .plot() and .scatter()
#
# The seaborn plots can automatically identify the current active Axes and apply the plot to it.
#
# You can have more then one axis per figure.

# %%
corrmat = df.corr()
fig, ax = plt.subplots(figsize=(14, 10))
sns.set(font_scale=1.25)
sns.heatmap(corrmat, annot=True, cbar=True, fmt='.2f');

#fig = plt.figure()
#ax = fig.add_subplot(111)

# %% [markdown]
# There does seem to have some negative linear correlation between all three DC voltages and the Board Temperature, but let's see how these values behave in more detail so that we can decide if we keep them in our analysis.

# %%
fig, axs = plt.subplots(ncols=3, figsize=(14, 4))
sns.regplot(x='3.3V IO', y='Board Temperature', data=df, ax=axs[0], fit_reg=False)
sns.regplot(x='5V Analogic', y='Board Temperature', data=df, ax=axs[1], fit_reg=False)
sns.regplot(x='3.3V Permanent',y='Board Temperature', data=df, ax=axs[2], fit_reg=False)

# %% [markdown]
# We can see the voltages only takes two or three values and they don't seem anomalous.
# I'm guessing we can safely drop these features.

# %%
df.drop(columns=['Record', '3.3V IO', '5V Analogic', '3.3V Permanent'], inplace=True)
df.head()
# Out:
#          Complete Date  Min Bat Voltage  Max Bat Voltage  Battery Current  \
# 0  04/04/2017 16:32:52         13.98047         13.98828         0.011719
# 1  04/04/2017 16:37:59         13.97656         13.98047         0.011719
# 2  04/04/2017 16:43:08         13.97656         13.98047         0.011719
# 3  04/04/2017 16:48:26         13.97266         13.97656         0.011719
# 4  04/04/2017 16:53:46         13.96875         13.97266         0.011719
#
#    Board Temperature
# 0                 23
# 1                 23
# 2                 23
# 3                 23
# 4                 22

# %%
df.dtypes
# Out:
# Complete Date         object
# Min Bat Voltage      float64
# Max Bat Voltage      float64
# Battery Current      float64
# Board Temperature      int64
# dtype: object

# %% [markdown]
# Now I'm going to make a plot of the 'Min Bat Voltage' column against the date column.
#
# In order to properly do that, we must first convert the date, stored until now as a string, to a datetime object, which was made to work with dates and have some nice methods like .days() or .month().

# %%
df['Complete Date'] = pd.to_datetime(df['Complete Date'])
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot_date(df['Complete Date'], df['Min Bat Voltage'])
fig.autofmt_xdate()  # show the dates on the x axis rotated for clarity
plt.ylabel('Min Bat Voltage')
plt.xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
# check the types of the columns, observe the datetime type
df.dtypes
# Out:
# Complete Date        datetime64[ns]
# Min Bat Voltage             float64
# Max Bat Voltage             float64
# Battery Current             float64
# Board Temperature             int64
# dtype: object

# %% [markdown]
# Now for a zoomed in version of the heatmap with fewer columns.

# %%
corrmat = df.corr()
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(corrmat, annot=True, cbar=True, fmt='.2f', ax=ax)

# %% [markdown]
# <br>
#
#
# This notebook will be updated often with other data analysis techniques, other plots etc.
